# %%
# !nvidia-smi
# Out:
# Sun Jun 13 14:30:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15097, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 15097 (delta 8), reused 9 (delta 2), pack-reused 15072
# Receiving objects: 100% (15097/15097), 13.45 MiB | 24.51 MiB/s, done.
# Resolving deltas: 100% (10252/10252), done.

# %%
# %cd ./darknet
# Out:
# /content/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:935:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1136:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# !./darknet detector train /content/drive/MyDrive/data_set/train.data /content/drive/MyDrive/data_set/training.cfg /content/drive/MyDrive/data_set/train/training_last.weights  -dont_show
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.812932), count: 3, class_loss = 0.339515, iou_loss = 0.134852, total_loss = 0.474367
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.518816), count: 3, class_loss = 0.595937, iou_loss = 0.606155, total_loss = 1.202092
#  total_bbox = 221478, rewritten_bbox = 1.691816 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.723832), count: 1, class_loss = 0.228421, iou_loss = 0.073439, total_loss = 0.301859
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.756122), count: 3, class_loss = 0.384177, iou_loss = 0.293313, total_loss = 0.677490
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.391046), count: 2, class_loss = 0.490472, iou_loss = 0.169398, total_loss = 0.659870
#  total_bbox = 221484, rewritten_bbox = 1.691770 %
# ...

# %%
//******* TEST ********
// For testing new image,edit last part of command
// You can see output --> under the darknet folder --> predictions.jpg
# !./darknet detector test /content/drive/MyDrive/data_set/train.data /content/drive/MyDrive/data_set/testing.cfg  /content/drive/MyDrive/data_set/train/training_2000.weights /content/drive/MyDrive/data_set/images/10.jpg
